# %%
from dep_grid.gadm import gadm

# %%
gadm["sqkm_3832"] = gadm.to_crs(3832).area / 1_000_000
gadm["sqkm_8859"] = gadm.to_crs(8859).area / 1_000_000

# %%
gadm
# Out:
#    GID_0                   COUNTRY  \
# 0    ASM            American Samoa
# 1    COK              Cook Islands
# 2    FJI                      Fiji
# 3    PYF          French Polynesia
# 4    GUM                      Guam
# 5    KIR                  Kiribati
# 6    MHL          Marshall Islands
# 7    FSM                Micronesia
# 8    NRU                     Nauru
# 9    NCL             New Caledonia
# 10   NIU                      Niue
# 11   MNP  Northern Mariana Islands
# 12   PLW                     Palau
# 13   PNG          Papua New Guinea
# 14   PCN          Pitcairn Islands
# 15   SLB           Solomon Islands
# 16   WSM                     Samoa
# 17   TKL                   Tokelau
# 18   TON                     Tonga
# 19   TUV                    Tuvalu
# 20   VUT                   Vanuatu
# 21   WLF         Wallis and Futuna
#
#                                              geometry      sqkm_3832  \
# ...
